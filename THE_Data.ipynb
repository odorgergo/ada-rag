# %%
# Import libraries
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get('https://www.timeshighereducation.com/sites/default/files/the_data_rankings/world_university_rankings_2018_limit0_369a9045a203e176392b9fb8f8c1cb2a.json')
table_body = r.json()

# %%
import pandas as pd
df = pd.DataFrame(table_body['data'])

# %%
ranking_complete=df[['rank', 'name', 'location', 'url', 'scores_overall', 'scores_teaching', 'scores_research', 
   'scores_citations', 'scores_industry_income', 'scores_international_outlook', 'stats_number_students',
   'stats_student_staff_ratio', 'stats_pc_intl_students']]

# %%
ranking_complete.head()
# Out:
#   rank                                   name        location  \
# 0    1                   University of Oxford  United Kingdom
# 1    2                University of Cambridge  United Kingdom
# 2   =3     California Institute of Technology   United States
# 3   =3                    Stanford University   United States
# 4    5  Massachusetts Institute of Technology   United States
#
#                                                  url scores_overall  \
# 0       /world-university-rankings/university-oxford           94.3
# 1    /world-university-rankings/university-cambridge           93.2
# 2  /world-university-rankings/california-institut...           93.0
# 3     /world-university-rankings/stanford-university           93.0
# 4  /world-university-rankings/massachusetts-insti...           92.5
#
#   scores_teaching scores_research scores_citations scores_industry_income  \
# 0            86.7            99.5             99.1                   63.7
# 1            87.8            97.8             97.5                   51.5
# 2            90.3            97.5             99.5                   92.6
# 3            89.1            96.7             99.9                   60.5
# 4            87.3            91.9            100.0                   88.4
#
#   scores_international_outlook stats_number_students  \
# 0                         95.0                20,409
# 1                         93.0                18,389
# 2                         59.7                 2,209
# 3                         77.6                15,845
# 4                         87.6                11,177
#
#   stats_student_staff_ratio stats_pc_intl_students
# 0                      11.2                    38%
# 1                      10.9                    35%
# 2                       6.5                    27%
# 3                       7.5                    22%
# 4                       8.7                    34%

# %%
ranking_complete.loc[:,'stats_pc_intl_students'] = ranking_complete['stats_pc_intl_students'].apply(lambda x: float(x.strip('%'))/100).head()
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:601: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
ranking_complete.head()
# Out:
#   rank                                   name        location  \
# 0    1                   University of Oxford  United Kingdom
# 1    2                University of Cambridge  United Kingdom
# 2   =3     California Institute of Technology   United States
# 3   =3                    Stanford University   United States
# 4    5  Massachusetts Institute of Technology   United States
#
#                                                  url scores_overall  \
# 0       /world-university-rankings/university-oxford           94.3
# 1    /world-university-rankings/university-cambridge           93.2
# 2  /world-university-rankings/california-institut...           93.0
# 3     /world-university-rankings/stanford-university           93.0
# 4  /world-university-rankings/massachusetts-insti...           92.5
#
#   scores_teaching scores_research scores_citations scores_industry_income  \
# 0            86.7            99.5             99.1                   63.7
# 1            87.8            97.8             97.5                   51.5
# 2            90.3            97.5             99.5                   92.6
# 3            89.1            96.7             99.9                   60.5
# 4            87.3            91.9            100.0                   88.4
#
#   scores_international_outlook stats_number_students  \
# 0                         95.0                20,409
# 1                         93.0                18,389
# 2                         59.7                 2,209
# 3                         77.6                15,845
# 4                         87.6                11,177
#
#   stats_student_staff_ratio  stats_pc_intl_students
# 0                      11.2                    0.38
# 1                      10.9                    0.35
# 2                       6.5                    0.27
# 3                       7.5                    0.22
# 4                       8.7                    0.34

# %%
ranking_complete.loc[:,'stats_number_students'] = ranking_complete.loc[:,'stats_number_students'].replace(',','',regex=True).values
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
ranking_complete.loc[:,'stats_number_students':'stats_student_staff_ratio'] = ranking_complete.loc[:,'stats_number_students':'stats_student_staff_ratio'].astype('float64')
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
ranking_complete.dtypes
# Out:
# rank                             object
# name                             object
# location                         object
# url                              object
# scores_overall                   object
# scores_teaching                  object
# scores_research                  object
# scores_citations                 object
# scores_industry_income           object
# scores_international_outlook     object
# stats_number_students           float64
# stats_student_staff_ratio       float64
# stats_pc_intl_students          float64
# dtype: object

# %%
ranking_complete.head()
# Out:
#   rank                                   name        location  \
# 0    1                   University of Oxford  United Kingdom
# 1    2                University of Cambridge  United Kingdom
# 2   =3     California Institute of Technology   United States
# 3   =3                    Stanford University   United States
# 4    5  Massachusetts Institute of Technology   United States
#
#                                                  url scores_overall  \
# 0       /world-university-rankings/university-oxford           94.3
# 1    /world-university-rankings/university-cambridge           93.2
# 2  /world-university-rankings/california-institut...           93.0
# 3     /world-university-rankings/stanford-university           93.0
# 4  /world-university-rankings/massachusetts-insti...           92.5
#
#   scores_teaching scores_research scores_citations scores_industry_income  \
# 0            86.7            99.5             99.1                   63.7
# 1            87.8            97.8             97.5                   51.5
# 2            90.3            97.5             99.5                   92.6
# 3            89.1            96.7             99.9                   60.5
# 4            87.3            91.9            100.0                   88.4
#
#   scores_international_outlook  stats_number_students  \
# 0                         95.0                20409.0
# 1                         93.0                18389.0
# 2                         59.7                 2209.0
# 3                         77.6                15845.0
# 4                         87.6                11177.0
#
#    stats_student_staff_ratio  stats_pc_intl_students
# 0                       11.2                    0.38
# 1                       10.9                    0.35
# 2                        6.5                    0.27
# 3                        7.5                    0.22
# 4                        8.7                    0.34

# %%
search = requests.get('https://google.co.uk/search?q=United+States')
search = search.text

# %%
soup = BeautifulSoup(search, 'html.parser')

# %%
soup.find_all('div', class_='_gdf kno-fb-ctx _LAf')
# Out:
# []
